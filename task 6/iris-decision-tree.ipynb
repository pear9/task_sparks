# %% [markdown]
# # Predicting the Species in Iris Dataset
#
# ### The purpose is if we feed any new data to this classifier, it would be able to predict the right class accordingly.
#
# ### Importing modules

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
# %matplotlib inline

pd.options.display.max_rows = 150

# %% [markdown]
# ## Loading CSV and Data Inspection

# %%
iris_df = pd.read_csv('https://raw.githubusercontent.com/pear9/task_sparks/master/task%206/Iris.csv',index_col = 'Id')
iris_df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
iris_df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
iris_df.Species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ### Checking for null values

# %%
iris_df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ### INSIGHT
# - No `Null` values.
# - No need of any datatype conversions.
# - Every species category have equal number of data points. Thus, the dataset is not biased

# %% [markdown]
# ## EDA
# ### CHECKING FOR OUTLIERS

# %%
plt.figure(figsize=(20,5))
j = 1
for i in iris_df.iloc[:,:-1].columns:
    plt.subplot(1,4,j)
    sns.boxplot(x=iris_df[i])
    j+=1

# %% [markdown]
# ### INSIGHT
# - Only `SepalWidthCm` is having outliers.
# - All other are not having any outliers.

# %% [markdown]
# ### Checking the distribution

# %%
plt.figure(figsize=(20,5))
j = 1
for i in iris_df.iloc[:,:-1].columns:
    plt.subplot(1,4,j)
    sns.distplot(iris_df[i])
    j+=1

# %% [markdown]
# ### INSIGHT
# - `SepalLengthCm`, `SepalWidthCm` are following `Normal Distribution`.
# - `PetalLengthCm`, `PetalWidthCm` are not following `Normal Distribution`. Thus, maybe much helpful when compared to other two in clustering.

# %%
sns.pairplot(iris_df,hue='Species')
plt.show()

# %% [markdown]
# ### INSIGHT
# - `PetalLengthCm`, `PetalWidthCm` columns are much more segmented between species when compared to other two.
# - In `scatter plot` between `SepalWidthCm` and `SepalLenthCm`, we cannot draw a border line between Species `versicolor` and `virginica`
# - Remaining plots look promising.

# %% [markdown]
# ## Data Preprocessing
# ### `Species` is the target variable here. So, y = `Species` and remaining features are X

# %%
X = iris_df.drop('Species',axis=1)
y = iris_df.Species
X.shape, y.shape
# Out:
# ((150, 4), (150,))

# %% [markdown]
# ### Train-Test Split

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.25, random_state=100)

# %% [markdown]
# ### Feature Scaling
# - Using `StandardScaler` to scale the training data

# %%
from sklearn.preprocessing import StandardScaler    
scaler= StandardScaler()  
X_train= scaler.fit_transform(X_train)    
X_test= scaler.transform(X_test)

# %% [markdown]
# ## MODEL BUILDING
# - Using `Decision Tree Classifier`
# - Using `GridSearchCV` to get best parameters which will not make model overfit

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

from sklearn.model_selection import RandomizedSearchCV
params={
    'criterion':['entropy','gini'],
    'max_depth':[5,6,7,8,9,10],
    'min_samples_leaf':[1,3,5,7,9]
}
rs=RandomizedSearchCV(DecisionTreeClassifier(),params,cv=10,n_jobs=-1,verbose=1)
rs.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# RandomizedSearchCV(cv=10, estimator=DecisionTreeClassifier(), n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [5, 6, 7, 8, 9, 10],
#                                         'min_samples_leaf': [1, 3, 5, 7, 9]},
#                    verbose=1)

# %%
r_df=pd.DataFrame(rs.cv_results_)
r_df[r_df['rank_test_score']==1]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5       0.001500      0.000499         0.000800        0.000600
# 7       0.001899      0.000830         0.000701        0.000641
#
#   param_min_samples_leaf param_max_depth param_criterion  \
# 5                      3               8            gini
# 7                      3               5            gini
#
#                                               params  split0_test_score  \
# 5  {'min_samples_leaf': 3, 'max_depth': 8, 'crite...                1.0
# 7  {'min_samples_leaf': 3, 'max_depth': 5, 'crite...                1.0
#
#    split1_test_score  ...  split3_test_score  split4_test_score  \
# 5                1.0  ...           0.909091                1.0
# 7                1.0  ...           0.909091                1.0
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 5                1.0                1.0                1.0                1.0
# 7                1.0                1.0                1.0                1.0
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 5                1.0         0.981818        0.036364                1
# 7                1.0         0.981818        0.036364                1
#
# [2 rows x 21 columns]

# %%
print('Score:',rs.best_score_,'\nParameters:', rs.best_params_)
# Out:
# Score: 0.9818181818181818
# Parameters: {'min_samples_leaf': 3, 'max_depth': 8, 'criterion': 'gini'}

# %%
best_classifier = rs.best_estimator_
best_classifier
# Out:
# DecisionTreeClassifier(max_depth=8, min_samples_leaf=3)

# %%
from sklearn.metrics import confusion_matrix

y_pred = best_classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[14,  0,  0],
#        [ 0,  9,  1],
#        [ 0,  1, 13]], dtype=int64)

# %% [markdown]
# ## MODEL EVALUATION
# ### Calculating `Accuracy` on the test data

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9473684210526315

# %% [markdown]
# ## Visualizing the `Decision Tree Model`

# %%
from sklearn import tree

fig = plt.figure(figsize=(25,20))
tree.plot_tree(best_classifier, feature_names=iris_df.columns, filled=True)
plt.show()

# %% [markdown]
# ## CONCLUSION
#
# <b> `Accuracy` of the `decision tree model` with `max_depth` at 5 and `min_samples_leaf` is 3 is `94.7%`</b>
